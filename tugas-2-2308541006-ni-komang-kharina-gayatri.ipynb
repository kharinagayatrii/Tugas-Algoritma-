# %%
Hutang1_06 = input("Berapakah hutang kamu di kantin? ")
Hutang2_06 = input("Berapakah hutang kamu di warung? ")
Total_hutang06 = int(Hutang1_06) + int(Hutang2_06)
print ("Total hutang kamu adalah Rp. " + str(Total_hutang06) + " INGAT BAYAR, HUTANG DIBAWA MATI :V")
# Out:
# Berapakah hutang kamu di kantin?  5000
# Berapakah hutang kamu di warung?  4000
# Total hutang kamu adalah Rp. 9000 INGAT BAYAR, HUTANG DIBAWA MATI :V

# %%
Nama06 = "Ni Komang Kharina Gayatri "
Status06 = "Mahasiswi "
Institusi06 = "Program Studi Matematika, Universitas Udayana "
print (f"{Nama06} adalah seorang {Status06} di {Institusi06}")
# Out:
# Ni Komang Kharina Gayatri  adalah seorang Mahasiswi  di Program Studi Matematika, Universitas Udayana

# %%
print ("Selamat datang di program FIND ME :D !!!")
Nama_anda06 = input ("Siapa nama kamu?")
print ("HII " + Nama_anda06 + ", ada tantangan untuk kamu nih. Temukan 3 nama hewan yang dapat terbentuk dari kata dibawah ini..semangat mencari yhhh;)")

Find_Me06 = "sayamaumeyakiniandalahpasangansehidupsematikusampainanti"
print (Find_Me06[41:-10]) 
print ("YEYY KAMU DAPAT 1 NAMA HEWAN, AYO 2 LAGI!")
# Out:
# Selamat datang di program FIND ME :D !!!
# Siapa nama kamu? kharina
# HII kharina, ada tantangan untuk kamu nih. Temukan 3 nama hewan yang dapat terbentuk dari kata dibawah ini..semangat mencari yhhh;)
# tikus
# YEYY KAMU DAPAT 1 NAMA HEWAN, AYO 2 LAGI!

# %%
judul06 = ("Kharina Wife Iqbaal")
print (judul06.upper())
# Out:
# KHARINA WIFE IQBAAL

# %%
print ("Selamat datang di program Matematika Cinta<3!!")
Tahun_anda06 = int(input ("Masukkan tahun kelahiran kamu "))
Tahun_pasangan06 = int(input ("Masukkan tahun kelahiran pasangan kamu "))

Selisih_usia06 = abs(Tahun_anda06 - Tahun_pasangan06)
print (f"Selisih usia kamu dengan pasangan kamu adalah {Selisih_usia06} tahun, tetapi cinta tidak memandang selisih usia yang terpenting adalah saling pengertian dan kesetiaan <3")
# Out:
# Selamat datang di program Matematika Cinta<3!!
# Masukkan tahun kelahiran kamu  2004
# Masukkan tahun kelahiran pasangan kamu  2003
# Selisih usia kamu dengan pasangan kamu adalah 1 tahun, tetapi cinta tidak memandang selisih usia yang terpenting adalah saling pengertian dan kesetiaan <3

# %%
x = 76348696973545**0 == 1
print(x)
# Out:
# True

# %%
perkalian06 = (1*2*1*2*1*2)
pembagian06 = (-1/2)
print(perkalian06 > 0 and pembagian06 < 0)
# Out:
# True

# %%
Nama_anda06 = input ("Nama kamu adalah ")
Nama_pasangan06 = input ("Nama pasangan kamu adalah ")
print ( Nama_anda06 + " adalah sinar di dunia " + Nama_pasangan06 )
print ("XOXO WUPYUUUU!!!:)")
# Out:
# Nama kamu adalah  kharina imyut
# Nama pasangan kamu adalah  a by unyu
# kharina imyut adalah sinar di dunia a by unyu
# XOXO WUPYUUUU!!!:)
