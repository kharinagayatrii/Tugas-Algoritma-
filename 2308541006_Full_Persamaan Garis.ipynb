# %%
print ("Soal: \nTerdapat persamaan garis yang melewati 2 titik, yaitu garis pertama yang melewati titik (h_06,a_06) dan (r_06,i_06) serta garis kedua yang melewati titik (m_06,n_06) dan (s_06,b_06). Terdapat 3 Kemungkinan dari kedua persamaan garis ini, yaitu \n1. Garis melewati 2 titik. \n2. Garis diketahui gradien dan titik yang dilewati. \n3. Megikuti persamaan garis ax+by=c dan dx+ey=f.")
print("===============================================SELAMAT DATANG==============================================")
print("==================================Program Penentu Grafik Persamaan Garis===================================")
import numpy as np
import matplotlib.pyplot as plt

print("\nKalian mau nentuin bagaimana bentuk kemungkinan-kemungkinan persamaan garis yang kalian punya? \nAYO IKUTIN RULES PROGRAM INI YA;)")
print("\n")

kemungkinan_06 = float(input ("Kemungkinan berapakah yang ingin kalian cari\n1. Berpotongan\n2. Berhimpit\n3. Sejajar"))
if kemungkinan_06 == 1 :
    print ("Masukkan titik-titik yang dilalui oleh garis pertama") #masukkan titik-titik garis pertama
    h_06 = float(input("Nilai x1 dari titik pertama garis pertama adalah "))
    a_06 = float(input("Nilai y1 dari titik pertama garis pertama adalah "))
    r_06 = float(input("Nilai x2 dari titik kedua garis pertama adalah "))
    i_06 = float(input("Nilai y2 dari titik kedua garis pertama adalah "))
    print ("Masukkan titik-titik yang dilalui oleh garis kedua") #masukkan titik-titik garis kedua
    m_06 = float(input("Nilai x1 dari titik pertama garis kedua adalah "))
    n_06 = float(input("Nilai y1 dari titik pertama garis kedua adalah "))
    s_06 = float(input("Nilai x2 dari titik kedua garis kedua adalah "))
    b_06 = float(input("Nilai y2 dari titik kedua garis kedua adalah "))

#Hitung gradien garis dari kedua persamaan garis
gradien1_06 = (i_06 - a_06)/(r_06 - h_06) # Gradien garis pertama
#subtitusi gradien dan titik titik yang diketahui ke y1_06=gradient1_06*(x_06-h_06)+a_06
gradien2_06 = (b_06 - n_06)/(s_06 - m_06) # Gradien garis kedua
#subtitusi gradien dan titik titik yang diketahui ke y2_06=Gradient2_06*(x_06-m_06)+n_06

#Mencari titik potong garis terhadap sumbu y
TIPO_1_06 = -gradien1_06*h_06+a_06 #titik potong persamaan garis pertama
TIPO_2_06 = -gradien2_06*m_06+n_06 #titik potong persamaan garis kedua

print("\n")
#persamaan garis pertama adalah y=gradien1_06(x-h_06)+a_06=gradien1_06x-gradien1_06(h_06+h_06)
print("Persamaan garis pertama adalah y={}x+{}".format(gradien1_06,TIPO_1_06))
#persamaan garis kedua adalah y=gradien2_06(x-m_06+n_06=gradien2_06x-gradien2_06(m_06+n_06)
print("Persamaan garis kedua adalah y={}x+{}\n".format(gradien2_06,TIPO_2_06))

if gradien1_06 == gradien2_06:
    print ("jika nilai gradien dari keduanya ternyata sama, terdpat 2 kemungkinan yang mungkin terjadi pada grafik garisnya yaitu berhimpit atau sejajar. Mari kita selidiki")
    if TIPO_1_06 == TIPO_2_06 :
        print("Ternyata jika kedua garisnya berhimpit") #garisnya berhimpit
        print(", maka diketahui bahwa memiliki tak berhingga solusi")
        x_06 = np.linspace(-5,5,100)
        plt.plot(x_06,gradien1_06*(x_06-h_06)+a_06,color="red", label="y={}(x-{})+{}".format(gradien1_06,h_06,a_06))
        plt.plot(x_06,gradien2_06*(x_06-m_06)+n_06,color="blue", label="y={}(x-{})+{}".format(gradien2_06,m_06,n_06))
        plt.axvline(x = 0,color='black')
        plt.axhline(y = 0,color='black')
        plt.title("Gambar Persamaan dimana Garis Berhimpit")
        plt.legend(loc='best')
        plt.grid(True)
        plt.show()
    else:
        print("Ternyata nilai gradiennya tidak sama, maka sudah pasti garisnya berpotongan")
        #mencari titik potong persamaan garis (TIPO_1_06,TIPO_2_06)
        TIPO_1_06 = (gradien1_06*h_06-a_06-gradien2_06*m_06+n_06)/(gradien1_06-gradien2_06) #titik potong persamaan garis 1
        TIPO_2_06 = gradien2_06*(TIPO_1_06-m_06)+n_06 #titik potong persamaan garis 2
        print("Maka titik potong kedua garis adalah ({},{})".format(TIPO_1_06,TIPO_2_06)+"\n")
        x_06 = np.linspace(TIPO_1_06-5,TIPO_1_06+5,100)
        plt.plot(x_06,gradien1_06*(x_06-h_06)+a_06,color='black',label="y={}(x-{})+{}".format(gradien1_06,h_06,a_06))
        plt.plot(x_06,gradien2_06*(x_06-m_06)+n_06,color='green',label="y={}(x-{})+{}".format(gradien2_06,m_06,n_06))
        plt.plot(TIPO_1_06,TIPO_2_06,color="red",marker="o",markersize=4)
        plt.axvline(x = 0,color='black')
        plt.axhline(y = 0,color='black')
        plt.title("Gambar Persamaan Garis Berpotongan")
        plt.legend(loc='best')
        plt.grid(True)
        plt.show()

#Kemungkinan 2
elif kemungkinan_06 == 2:
    print("Masing-masing garis diketahui gradien dan titik yang dilewati.") #gradien dan titik-titi persamaaan garis 1
    gradien1_06 = float(input("Masukkan Gradien dari garis pertama: "))
    h_06 = float(input("Nilai x dari titik yang dilewati oleh garis pertama: "))
    a_06 = float(input("Nilai y dari titik yang dilewati oleh garis pertama: "))
    print("Persamaan garis pertama adalah y={}(x-{})+{}".format(gradien1_06,h_06,a_06)) #gradien dan titik-titi persamaaan garis 1
    gradien2_06 = float(input("Masukkan Gradien dari garis kedua: "))
    m_06 = float(input("Nilai x dari titik yang dilewati oleh garis kedua: "))
    n_06 = float(input("Nilai y dari titik yang dilewati oleh garis kedua: "))
    print("Persamaan garis kedua adalah y={}(x-{})+{}".format(gradien2_06,m_06,n_06))

    #mencari titik potong persamaan garis (TIPO_1_06,TIPO_2_06)
    TIPO1_06 = -gradien1_06*h_06+a_06
    TIPO2_06 = -gradien2_06*m_06+n_06

    print("\n")
    print("Persamaan garis pertama adalah y={}x+{}".format(gradien1_06,TIPO1_06))
    print("Persamaan garis kedua adalah y={}x+{}\n".format(gradien2_06,TIPO2_06))

    if gradien1_06 == gradien2_06:
        print("Ternyata gradien keduanya sama, jadi kemungkinan garisnya bisa sejajar atau berhimpit")
        if TIPO1_06 == TIPO2_06:
            print("jika ternyata garis berhimpit") #garisnya berhimpit
            print(", maka memiliki banyak solusi penyelesaian")
            x_06 = np.linspace(-5,5,100)
            plt.plot(x_06,gradien1_06*(x_06-h_06)+a_06,color="red", linestyle = "--", label = "y= {}x+{}".format(gradien1_06,TIPO1_06))
            plt.plot(x_06,gradien2_06*(x_06-m_06)+n_06,color="blue", label = "y= {}x+{}".format(gradien2_06,TIPO2_06))
            plt.axvline(x=0,color='black')
            plt.axhline(y=0,color='black')
            plt.title("Gambar Persamaan Garis Berhimpit")
            plt.legend(loc='best')
            plt.grid(True)
            plt.show()
        else:
            print("Jika ternyata garisnya sejajar") #garisnya sejajar
            print(", maka tidak memiliki solusi penyelesaian")
            x_06 = np.linspace(-5,5,100)
            plt.plot(x_06,gradien1_06*(x_06-h_06)+a_06,color="black", linestyle = "--", label = "y={}x+{}".format(gradien1_06,TIPO1_06))
            plt.plot(x_06,gradien2_06*(x_06-m_06)+n_06,color="green", label = "y={}x+{}".format(gradien2_06,TIPO2_06))
            plt.axvline(x=0,color='black')
            plt.axhline(y=0,color='black')
            plt.title("Gambar Persamaan Garis Sejajar")
            plt.legend(loc='best')
            plt.grid(True)
            plt.show()
    else:
        print("Ternyata gradiennya tidak sama, maka sudah pasti garisnya berpotongan di satu titik") #mencari titik potong persamaan garis (TIPO_1_06,TIPO_2_06)
        TIPO_1_06 = (gradien1_06*h_06-a_06-gradien2_06*m_06+n_06)/(gradien1_06-gradien2_06) #titik potong persamaan garis 1
        TIPO_2_06 = gradien2_06*(TIPO_1_06-m_06)+n_06 #titik potong persamaan garis 2
        print ("jadi titik potong kedua garis adalah ({},{})".format(TIPO_1_06,TIPO_2_06)+"\n")
        x_06 = np.linspace(TIPO_1_06-5,TIPO_1_06+5,100)
        plt.plot(x_06,gradien1_06*(x_06-h_06)+a_06,color='red',label="y={}(x-{})+{}".format(gradien1_06,h_06,a_06))
        plt.plot(x_06,gradien2_06*(x_06-m_06)+n_06,color='blue',label="y={}(x-{})+{}".format(gradien2_06,m_06,n_06))
        plt.plot(TIPO_1_06,TIPO_2_06,color="green",marker="o",markersize=4)
        plt.axvline(x=0,color='black')
        plt.axhline(y=0,color='black')
        plt.title("Gambar Persamaan Garis Berpotongan")
        plt.legend(loc='best')
        plt.grid(True)
        plt.show()

#Kemungkinan 3
elif kemungkinan_3 == 3:
    print("Kedua garis memenuhi persamaan berbentuk dx+iy=a dan bx+ey=s.")
    #masukkan elemen-elemen pembuat persamaan kedua
    h_06 = float(input("Koefisien dari x pada garis pertama adalah: "))
    a_06 = float(input("Koefisien dari y pada garis pertama adalah: "))
    r_06 = float(input("Konstanta dari garis pertama adalah: "))
    #masukkan elemen-elemen pembuat persamaan kedua
    m_06 = float(input("Koefisien dari x pada garis kedua adalah: "))
    n_06 = float(input("Koefisien dari y pada garis kedua adalah: "))
    s_06 = float(input("Konstanta dari garis kedua adalah: "))
    #mencari gradien kedua persamaan garis dari titik-titik yang diketahui
    gradien1_06 = ((-h_06)/a_06) # Gradien garis pertama
    gradien2_06= (-m_06)/(n_06) # Gradien garis kedua​
    #mencari titik potong garis terhadap sumbu y
    TIPO1_06 = r_06/a_06 # Titik potong garis pertama terhadap sumbu y
    TIPO2_06 = s_06/n_06 # titik potong garis kedua terhadap sumbu y garis kedua

    print("persamaan garis 1 adalah \t: y= ({}x)+{}".format(gradien1_06,TIPO1_06))
    print("persamaan garis 2 adalah \t: y= ({}x)+{}".format(gradien2_06,TIPO2_06))

    if gradien1_06 == gradien2_06:
        print("Jika ternyata nilai dari kedua gradien sama, maka kemungkinan garisnya sejajar atau berhimpit")
        if TIPO1_06 == TIPO2_06:
            print("Ternyata garisnya berhimpit")
            print(", maka memiliki banyak solusi penyelesaian")
            x_06 = np.linspace(-5,5,100)
            plt.plot(x_06,(gradien1_06*x_06)+TIPO1_06,color="darkbrown", linestyle = "--", label="line 1")
            plt.plot(x_15,(m2_15*x_15)+tp2_15,color="lightbrown",label="line 2")
            plt.axvline(x=0,color='black')
            plt.axhline(y=0,color='black')
            plt.title("Gambar Persamaan Garis Berhimpit")
            plt.legend(loc='best')
            plt.grid(True)
            plt.show()
        else:
            print("Ternyata garisnya sejajar")
            print(", maka tidak memiliki solusi penyelesaian")
            x_06 = np.linspace(-5,5,100)
            plt.plot(x_06,(gradien1_06*x_06)+TIPO1_06,color="darkbrown", linestyle = "--", label="line 1")
            plt.plot(x_06,(gradien2_06*x_06)+TIPO2_06,color="lightbrown",label="line 2")
            plt.axvline(x=0,color='black')
            plt.axhline(y=0,color='black')
            plt.title("Gambar Persamaan Garis Sejajar")
            plt.legend(loc='best')
            plt.grid(True)
            plt.show()
    else:
        print("Ternyata gradiennya tidak samaa, maka sudah pasti garisnya berpotongan di satu titik")
        print("ayo kita hitung titik potongnya dengan bantuan matriks! ")
        #tentukan matriks koefisien A dan matriks konstanta B
        A_06 = np.array([[h_06, m_06], [a_06,n_06]])
        B_06 = np.array([r_06, s_06])
        print("Matriks dari koefisien x dan y yaitu: \n", A_06)
        print("Matriks konstanta dari kedua persamaan garis yaitu: \n", B_06)
        #untuk menghitung titik potong dari dua persamaan diatas, maka akan dihitung invers matriks A dikali dengan Matriks B
        #akan dihitung invers dari matriks A dengan rumus numpy
        Ainvers_06 = np.linalg.inv(A_06)
        print("Invers dari Matriks A yaitu: \n", Ainvers_06)
        # Selesaikan sistem persamaan linear menggunakan fungsi np.linalg.dot
        xy_06 = np.dot((Ainvers_06),(B_06))
        print("titik potongnya adalah : \n [x,y]=", xy_06)
        #ayo gambar persamaaan garisnya
        x_06 = np.linspace(xy_06-5,xy_06+5,100)
        plt.plot(x_06,(gradien1_06*x_06)+TIPO1_06,color="green",label="y= ({}x)+{}".format(gradien1_06,TIPO1_06))
        plt.plot(x_06,(gradien2_06*x_06)+TIPO2_06,color="yellow",label="y= ({}x)+{}".format(gradien2_06,TIPO2_06))
        plt.axvline(x=0,color='black')
        plt.axhline(y=0,color='black')
        plt.title("Gambar Persamaan Garis Berpotongan")
        plt.legend(loc='best')
        plt.grid(True)
        plt.show()
else:
    print("Tidak bisa selain pilihan 1, 2, dan 3 yaa.. terima kasih")
# Out:
# Soal:
# Terdapat persamaan garis yang melewati 2 titik, yaitu garis pertama yang melewati titik (h_06,a_06) dan (r_06,i_06) serta garis kedua yang melewati titik (m_06,n_06) dan (s_06,b_06). Terdapat 3 Kemungkinan dari kedua persamaan garis ini, yaitu
# 1. Garis melewati 2 titik.
# 2. Garis diketahui gradien dan titik yang dilewati.
# 3. Megikuti persamaan garis ax+by=c dan dx+ey=f.
# ===============================================SELAMAT DATANG==============================================
# ==================================Program Penentu Grafik Persamaan Garis===================================
#
# Kalian mau nentuin bagaimana bentuk kemungkinan-kemungkinan persamaan garis yang kalian punya?
# AYO IKUTIN RULES PROGRAM INI YA;)
#
#
# Kemungkinan berapakah yang ingin kalian cari
# 1. Berpotongan
# 2. Berhimpit
# 3. Sejajar1
# Masukkan titik-titik yang dilalui oleh garis pertama
# Nilai x1 dari titik pertama garis pertama adalah 2
# ...
