# %%
Tahun_anda06 = int(input("Masukkan tahun kelahiran kamu "))
Tahun_pasangan06 = int(input("Masukkan tahun kelahiran pasangan kamu"))
Selisih_umur06 = abs(Tahun_anda06 - Tahun_pasangan06)
print(f"selisih usia kamu dengan psangan kamu adalah {Selisih_umur06} tahun")
if Selisih_umur06 <= 5: 
    print("WOW kalian pasangan yang memiliki selisih usia tidak terlalu jauh")
    print("Mungkin itu akan membuat hubungan kalian lebih dekat")
if Selisih_umur06 > 5:
    print("Selisih umur kalian yang cukup berumur")
    print("tetapi cinta tak mengenal usia langgeng yh")
# Out:
# Masukkan tahun kelahiran kamu  2004
# Masukkan tahun kelahiran pasangan kamu 2003
# selisih usia kamu dengan psangan kamu adalah 1 tahun
# WOW kalian pasangan yang memiliki selisih usia tidak terlalu jauh
# Mungkin itu akan membuat hubungan kalian lebih dekat

# %%
a = 8
b = 8
while a > 1:
    print(a * "$" + (b-a) * ' ' + a * '$')
    a -= 1
    b += 1
print ("🖤🖤🖤🖤🖤🖤🖤")    
a = 0
while a < 6:
    print("🖤🖤" + "       " + "🖤🖤")
    a += 1
print ("🖤🖤🖤🖤🖤🖤🖤")
# Out:
# $$$$$$$$$$$$$$$$
# $$$$$$$  $$$$$$$
# $$$$$$    $$$$$$
# $$$$$      $$$$$
# $$$$        $$$$
# $$$          $$$
# $$            $$
# 🖤🖤🖤🖤🖤🖤🖤
# 🖤🖤       🖤🖤
# 🖤🖤       🖤🖤
# 🖤🖤       🖤🖤
# 🖤🖤       🖤🖤
# 🖤🖤       🖤🖤
# 🖤🖤       🖤🖤
# 🖤🖤🖤🖤🖤🖤🖤
