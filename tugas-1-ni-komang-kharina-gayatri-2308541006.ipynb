# %%
def main():
    nama_anda06 = input("Masukkan nama Anda: ")
    nama_pasangan06 = input("Masukkan nama pasangan Anda: ")

    print("\nCinta adalah sesuatu yang indah,")
    print("Dari", nama_anda06, "untuk", nama_pasangan06 + ",")
    print("Cinta adalah sebuah perjalanan panjang,")
    print("Yang penuh dengan kebahagiaan dan keajaiban.")

if __name__ == "__main__":
    main()
# Out:
# Masukkan nama Anda:  Kharina
# Masukkan nama pasangan Anda:  Iqbaal
# Cinta adalah sesuatu yang indah,
# Dari Kharina untuk Iqbaal,
# Cinta adalah sebuah perjalanan panjang,
# Yang penuh dengan kebahagiaan dan keajaiban.
